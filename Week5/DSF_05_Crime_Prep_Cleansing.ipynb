# %% [markdown]
# # <font color='darkblue'>__Data Science Fundamentals__</font>
# ## <font color='darkblue'>__Data Cleanup & Preparation__</font>
# ###
# ### <font color='darkblue'>__Example on Crime Data from Boston__</font>
# #### <font color='darkblue'>Source of the data: https://www.kaggle.com/AnalyzeBoston/crimes-in-boston</font>
# ###

# %% [markdown]
# __[1. Basic Cleansing](#c1)__<br>
# $\;\;\;\;\;$[Data load (for Basic Cleansing)](#data_load)<br>
# $\;\;\;\;\;$[Descriptive Statistics](#desc)<br>
# $\;\;\;\;\;$[Check the data format and change it](#format)<br>
# $\;\;\;\;\;$[Check for empty entries and remove them](#nulls)<br>
# $\;\;\;\;\;$[Check for duplicates and remove them](#duplicates)<br>
# $\;\;\;\;\;$[Check for outliers](#outliers)<br>
#
# __[2. Transformation & Aggregation](#c2)__<br>
# $\;\;\;\;\;$[Data load (for Transformation & Aggregation)](#data_load)<br>
# $\;\;\;\;\;$[Remove](#remove)<br>
# $\;\;\;\;\;$[Concatenate](#concatenate)<br>
# $\;\;\;\;\;$[Append](#append)<br>
# $\;\;\;\;\;$[Join](#join)<br>
# $\;\;\;\;\;$[Merge](#merge)<br>
# $\;\;\;\;\;$[Aggregate](#aggregate)<br>
# $\;\;\;\;\;$[Group by](#groupby)<br>

# %% [markdown]
# ## <a id='c1'></a>
# ## <font color='darkblue'>__1. Basic Cleansing__</font>

# %% [markdown]
# ## <a id='data_load'></a>
# ### <font color='darkblue'>__Data load (for Basic Cleansing)__</font>

# %% [markdown]
# #### <font color='darkblue'>__→ All data__</font>

# %%
# Load the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
# print(style.available)
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

# %%
# Read data from your prepared example .csv-file into a dataframe (define seperator)
df = pd.read_csv("data/Crime/crime_robbery_burglary_unclean.csv", delimiter=';', header=None, skiprows=1, names=['INCIDENT_NUMBER', 'OFFENSE_CODE', 'OFFENSE_CODE_GROUP', 'OFFENSE_CODE_GROUP_No', 'OFFENSE_DESCRIPTION', 'DISTRICT', 'District_simple',
                 'District_simple_No', 'REPORTING_AREA', 'OCCURRED_ON_DATE', 'Hour1', 'Start_Night', 'Start_Day', 'Night_Day', 'YEAR', 'MONTH', 'DAY_OF_WEEK', 'WE_Workday', 'WE_Workday_No', 'HOUR', 'Counts_per_hour', 'STREET', 'Lat', 'Long', 'Location'], index_col=False)

# Option: Short version for import
# pd.read_csv('data/Crime/crime_robbery_burglary.csv', index_col=False)
# df = pd.DataFrame(crimedata)
# df

# Show the content of the dataframe:
df

# Option: Print the header info of data (first five rows)
# df.head(5)
# Out:
#      INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP  \
# 0         I182070908           522  Residential Burglary
# 1         I182070908           522  Residential Burglary
# 2         I182070813           522  Residential Burglary
# 3         I182070804           522  Residential Burglary
# 4         I182070706           520  Residential Burglary
# ...              ...           ...                   ...
# 4747      I162087225           301               Robbery
# 4748      I162087026           301               Robbery
# 4749      I162086984           311               Robbery
# 4750      I162086982           301               Robbery
# 4751      I162086948           301               Robbery
#
#       OFFENSE_CODE_GROUP_No                OFFENSE_DESCRIPTION DISTRICT  \
# 0                         1  BURGLARY - RESIDENTIAL - NO FORCE       B2
# 1                         1  BURGLARY - RESIDENTIAL - NO FORCE       B2
# 2                         1          BURGLARY - RES - NO FORCE       D4
# 3                         1  BURGLARY - RESIDENTIAL - NO FORCE      D14
# 4                         1     BURGLARY - RESIDENTIAL - FORCE      C11
# ...                     ...                                ...      ...
# 4747                      2                   ROBBERY - STREET       B2
# 4748                      2                   ROBBERY - STREET       A1
# 4749                      2               ROBBERY - COMMERCIAL       B3
# 4750                      2                   ROBBERY - STREET      E18
# 4751                      2                   ROBBERY - STREET       C6
#
#      District_simple  District_simple_No  REPORTING_AREA  OCCURRED_ON_DATE  \
# 0                  B                   2             911  03.09.2018 18:38
# 1                  B                   2             911  03.09.2018 18:38
# 2                  D                   4             627  03.09.2018 03:00
# 3                  D                   4             756  03.09.2018 11:00
# 4                  C                   3             402  02.09.2018 23:33
# ...              ...                 ...             ...               ...
# 4747               B                   2             909  24.10.2016 16:47
# 4748               A                   1             120  24.10.2016 03:40
# 4749               B                   2             469  23.10.2016 20:35
# 4750               E                   5             498  23.10.2016 21:18
# 4751               C                   3             214  22.10.2016 18:00
#
#       ... MONTH DAY_OF_WEEK WE_Workday WE_Workday_No  HOUR  Counts_per_hour  \
# 0     ...     9      Monday   Workdays             1    18              285
# 1     ...     9      Monday   Workdays             1    18              285
# 2     ...     9      Monday   Workdays             1     3              124
# 3     ...     9      Monday   Workdays             1    11              193
# 4     ...     9      Sunday    Weekend             2    23              231
# ...   ...   ...         ...        ...           ...   ...              ...
# 4747  ...    10      Monday   Workdays             1    16              231
# 4748  ...    10      Monday   Workdays             1     3              124
# 4749  ...    10      Sunday    Weekend             2    20              305
# 4750  ...    10      Sunday    Weekend             2    21              303
# 4751  ...    10    Saturday    Weekend             2    18              285
#
#                STREET        Lat       Long                     Location
# 0     ANNUNCIATION RD  42.335062 -71.093168  (42.33506218, -71.09316781)
# 1     ANNUNCIATION RD  42.335062 -71.093168  (42.33506218, -71.09316781)
# 2     PETERBOROUGH ST  42.342802 -71.100695  (42.34280177, -71.10069510)
# 3         CHAMPNEY ST  42.352412 -71.168788  (42.35241230, -71.16878833)
# 4             BURT ST  42.284135 -71.069574  (42.28413536, -71.06957385)
# ...               ...        ...        ...                          ...
# 4747         CABOT ST  42.333382 -71.087454  (42.33338200, -71.08745421)
# 4748      BOYLSTON ST  42.352418 -71.065255  (42.35241815, -71.06525499)
# 4749     WALK HILL ST  42.280827 -71.097547  (42.28082671, -71.09754718)
# 4750       NAVARRE ST  42.274581 -71.117665  (42.27458078, -71.11766502)
# 4751          GOLD ST  42.336295 -71.049717  (42.33629453, -71.04971704)
#
# [4752 rows x 25 columns]

# %% [markdown]
# ## <a id='desc'></a>
# ### <font color='darkblue'>__Descriptive Statistics__</font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4752 entries, 0 to 4751
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   INCIDENT_NUMBER        4752 non-null   object
#  1   OFFENSE_CODE           4752 non-null   int64
#  2   OFFENSE_CODE_GROUP     4752 non-null   object
#  3   OFFENSE_CODE_GROUP_No  4752 non-null   int64
#  4   OFFENSE_DESCRIPTION    4749 non-null   object
#  5   DISTRICT               4752 non-null   object
#  6   District_simple        4746 non-null   object
#  7   District_simple_No     4752 non-null   int64
#  8   REPORTING_AREA         4752 non-null   int64
#  9   OCCURRED_ON_DATE       4752 non-null   object
#  10  Hour1                  4752 non-null   object
#  11  Start_Night            4752 non-null   object
#  12  Start_Day              4752 non-null   object
#  13  Night_Day              4752 non-null   object
#  14  YEAR                   4752 non-null   int64
#  15  MONTH                  4752 non-null   int64
#  16  DAY_OF_WEEK            4752 non-null   object
#  17  WE_Workday             4752 non-null   object
#  18  WE_Workday_No          4752 non-null   int64
#  19  HOUR                   4752 non-null   int64
#  20  Counts_per_hour        4752 non-null   int64
#  21  STREET                 4752 non-null   object
#  22  Lat                    4752 non-null   float64
#  23  Long                   4752 non-null   float64
#  24  Location               4752 non-null   object
# dtypes: float64(2), int64(9), object(14)
# memory usage: 928.3+ KB

# %%
df.describe()
# Out:
#        OFFENSE_CODE  OFFENSE_CODE_GROUP_No  District_simple_No  \
# count   4752.000000            4752.000000         4752.000000
# mean     423.189815               1.477273            2.891414
# std      103.727028               0.499536            1.324285
# min      301.000000               1.000000            1.000000
# 25%      301.000000               1.000000            2.000000
# 50%      520.000000               1.000000            3.000000
# 75%      521.000000               2.000000            4.000000
# max      522.000000               2.000000            5.000000
#
#        REPORTING_AREA         YEAR        MONTH  WE_Workday_No         HOUR  \
# count     4752.000000  4752.000000  4752.000000    4752.000000  4752.000000
# mean       396.626684  2017.246843     6.289983       1.262205    13.162668
# std        245.430197     0.601243     3.495145       0.439880     6.831546
# min          2.000000  2015.000000     1.000000       1.000000     0.000000
# 25%        186.000000  2017.000000     3.000000       1.000000     8.000000
# 50%        356.000000  2017.000000     6.000000       1.000000    14.000000
# 75%        576.250000  2018.000000     9.000000       2.000000    19.000000
# max        961.000000  2018.000000    12.000000       2.000000    23.000000
#
#        Counts_per_hour          Lat         Long
# count      4752.000000  4752.000000  4752.000000
# mean        229.008207    42.322904   -71.083054
# std          57.736759     0.031284     0.029948
# min          77.000000    42.232870   -71.172440
# 25%         193.000000    42.300217   -71.099294
# 50%         241.000000    42.324694   -71.078177
# 75%         277.000000    42.347208   -71.062613
# max         305.000000    42.392146   -70.997852

# %%
# Minimale Anzahl Fälle pro Stunde
min_cons = df['Counts_per_hour'].min()

# Maximale Anzahl Fälle pro Stunde
max_cons = df['Counts_per_hour'].max()

# Durchschnittliche Anzahl Fälle pro Stunde
mean_cons = (df['Counts_per_hour'].mean())

# Median der Anzahl Fälle pro Stunde
median_cons = df['Counts_per_hour'].median()

# Standardabweichung Anzahl Fälle pro Stunde
std_cons = df['Counts_per_hour'].std()

# %%
# Print-Statement der berechneten Variablen
print("Basic statistics of the burglary dataset:\n")
print("Minimum number of cases per hour:")
print(min_cons)
print(" \n")
print("Maximum number of cases per hour:")
print(max_cons)
print(" \n")
print("Average number of cases per hour")
print(mean_cons)
print(" \n")
print("Median number of cases per hour:")
print(median_cons)
print(" \n")
print("Standard deviation Number of cases per hour:")
print(std_cons)
print(" \n")
print("Number of entries in the record: {}".format(df.shape[0]))
print("Number of columns in the record: {}".format(df.shape[1]))
# Out:
# Basic statistics of the burglary dataset:
#
# Minimum number of cases per hour:
# 77
#
#
# Maximum number of cases per hour:
# 305
#
#
# Average number of cases per hour
# 229.00820707070707
#
#
# Median number of cases per hour:
# 241.0
#
#
# Standard deviation Number of cases per hour:
# 57.73675860340113
#
#
# Number of entries in the record: 4752
# Number of columns in the record: 25

# %% [markdown]
# ## <a id='format'></a>
# ### <font color='darkblue'>__Check for format and change it__</font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4752 entries, 0 to 4751
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   INCIDENT_NUMBER        4752 non-null   object
#  1   OFFENSE_CODE           4752 non-null   int64
#  2   OFFENSE_CODE_GROUP     4752 non-null   object
#  3   OFFENSE_CODE_GROUP_No  4752 non-null   int64
#  4   OFFENSE_DESCRIPTION    4749 non-null   object
#  5   DISTRICT               4752 non-null   object
#  6   District_simple        4746 non-null   object
#  7   District_simple_No     4752 non-null   int64
#  8   REPORTING_AREA         4752 non-null   int64
#  9   OCCURRED_ON_DATE       4752 non-null   object
#  10  Hour1                  4752 non-null   object
#  11  Start_Night            4752 non-null   object
#  12  Start_Day              4752 non-null   object
#  13  Night_Day              4752 non-null   object
#  14  YEAR                   4752 non-null   int64
#  15  MONTH                  4752 non-null   int64
#  16  DAY_OF_WEEK            4752 non-null   object
#  17  WE_Workday             4752 non-null   object
#  18  WE_Workday_No          4752 non-null   int64
#  19  HOUR                   4752 non-null   int64
#  20  Counts_per_hour        4752 non-null   int64
#  21  STREET                 4752 non-null   object
#  22  Lat                    4752 non-null   float64
#  23  Long                   4752 non-null   float64
#  24  Location               4752 non-null   object
# dtypes: float64(2), int64(9), object(14)
# memory usage: 928.3+ KB

# %% [markdown]
# ## <a id='nulls'></a>
# ### <font color='darkblue'>__Check for empty entries and remove them__</font>

# %%
df.isnull().sum()
# Out:
# INCIDENT_NUMBER          0
# OFFENSE_CODE             0
# OFFENSE_CODE_GROUP       0
# OFFENSE_CODE_GROUP_No    0
# OFFENSE_DESCRIPTION      3
# DISTRICT                 0
# District_simple          6
# District_simple_No       0
# REPORTING_AREA           0
# OCCURRED_ON_DATE         0
# Hour1                    0
# Start_Night              0
# Start_Day                0
# Night_Day                0
# YEAR                     0
# MONTH                    0
# DAY_OF_WEEK              0
# WE_Workday               0
# WE_Workday_No            0
# HOUR                     0
# Counts_per_hour          0
# STREET                   0
# Lat                      0
# Long                     0
# Location                 0
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# INCIDENT_NUMBER          0
# OFFENSE_CODE             0
# OFFENSE_CODE_GROUP       0
# OFFENSE_CODE_GROUP_No    0
# OFFENSE_DESCRIPTION      0
# DISTRICT                 0
# District_simple          0
# District_simple_No       0
# REPORTING_AREA           0
# OCCURRED_ON_DATE         0
# Hour1                    0
# Start_Night              0
# Start_Day                0
# Night_Day                0
# YEAR                     0
# MONTH                    0
# DAY_OF_WEEK              0
# WE_Workday               0
# WE_Workday_No            0
# HOUR                     0
# Counts_per_hour          0
# STREET                   0
# Lat                      0
# Long                     0
# Location                 0
# dtype: int64

# %% [markdown]
# ## <a id='duplicates'></a>
# ### <font color='darkblue'>__Check for duplicates and remove them__</font>

# %%
df.duplicated()
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 4747    False
# 4748    False
# 4749    False
# 4750    False
# 4751    False
# Length: 4743, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df = df.drop_duplicates()
df.duplicated()
# Out:
# 0       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 4747    False
# 4748    False
# 4749    False
# 4750    False
# 4751    False
# Length: 4742, dtype: bool

# %% [markdown]
# ## <a id='outliers'></a>
# ### <font color='darkblue'>__Check for outliers__</font>

# %%
df_contiuous = df[["REPORTING_AREA", "YEAR", "MONTH",
                   "HOUR", "Counts_per_hour", "Lat", "Long"]]

# %%
df_contiuous.plot(kind="box", subplots=True, layout=(5, 5),
                  fontsize=12, figsize=(25, 16))

# %%
df_new = df[["Long"]]
sns.catplot(kind="box", data=df_new, height=5, aspect=0.7)
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Caluclating the whiskers:
def iqr_fences(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    lowerFence = Q1 - (1.5 * IQR)
    upperFence = Q3 + (1.5 * IQR)
    return lowerFence, upperFence

# %%
for label, content in df_contiuous.items():
    Q1 = content.quantile(0.25)
    Q3 = content.quantile(0.75)
    IQR = Q3 - Q1
    v_col = content[(content <= Q1 - 1.5 * IQR) | (content >= Q3 + 1.5 * IQR)]
    perc = np.shape(v_col)[0] * 100.0 / np.shape(df)[0]
    print("Spalte {} Anteil an Outliers = {}%".format(label, round(perc, 2)))
# Out:
# Spalte REPORTING_AREA Anteil an Outliers = 0.0%
# Spalte YEAR Anteil an Outliers = 0.02%
# Spalte MONTH Anteil an Outliers = 0.0%
# Spalte HOUR Anteil an Outliers = 0.0%
# Spalte Counts_per_hour Anteil an Outliers = 0.0%
# Spalte Lat Anteil an Outliers = 0.0%
# Spalte Long Anteil an Outliers = 2.74%

# %%
for i in df_contiuous.columns:
    result = iqr_fences(df[i])
    lowerFence = result[0]
    upperFence = result[1]
    print("Lower Fence of {}: {}".format(i, lowerFence))
    print("Upper Fence of {}: {}".format(i, upperFence))
# Out:
# Lower Fence of REPORTING_AREA: -399.0
# Upper Fence of REPORTING_AREA: 1161.0
# Lower Fence of YEAR: 2015.5
# Upper Fence of YEAR: 2019.5
# Lower Fence of MONTH: -6.0
# Upper Fence of MONTH: 18.0
# Lower Fence of HOUR: -8.5
# Upper Fence of HOUR: 35.5
# Lower Fence of Counts_per_hour: 67.0
# Upper Fence of Counts_per_hour: 403.0
# Lower Fence of Lat: 42.22962846374999
# Upper Fence of Lat: 42.41786413375
# Lower Fence of Long: -71.15422621250002
# Upper Fence of Long: -71.0076354725

# %%
lowerFence, upperFence = iqr_fences(df['Counts_per_hour'])

# Print Statement for whiskers:
print("Min-Whisker: {}".format((lowerFence*1000).round(2)))
print("Max-Whisker: {}".format((upperFence*1000).round(2)))
# Out:
# Min-Whisker: 67000.0
# Max-Whisker: 403000.0

# %%
# Print number of records which are below and above the max whisker:
print(len(df[df['Counts_per_hour'] > 403000]))
print(len(df[df['Counts_per_hour'] < 403000]))
# Out:
# 0
# 4742

# %%
Q1 = df['Counts_per_hour'].quantile(0.25)
Q3 = df['Counts_per_hour'].quantile(0.75)
IQR = Q3 - Q1
MaxW = Q3 + 1.5*IQR
MinW = Q1 - 1.5*IQR

Max_Cons = df[df['Counts_per_hour'] > MaxW]
Max_Cons
# Out:
# Empty DataFrame
# Columns: [INCIDENT_NUMBER, OFFENSE_CODE, OFFENSE_CODE_GROUP, OFFENSE_CODE_GROUP_No, OFFENSE_DESCRIPTION, DISTRICT, District_simple, District_simple_No, REPORTING_AREA, OCCURRED_ON_DATE, Hour1, Start_Night, Start_Day, Night_Day, YEAR, MONTH, DAY_OF_WEEK, WE_Workday, WE_Workday_No, HOUR, Counts_per_hour, STREET, Lat, Long, Location]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# ## <a id='c2'></a>
# ## <font color='darkblue'>__2. Transformation & Aggregation__</font>

# %% [markdown]
# ## <a id='data_load'></a>
# ### <font color='darkblue'>__Data load (for Transformation & Aggregation)__</font>

# %% [markdown]
# #### <font color='darkblue'>__→ All data__</font>

# %%
# Load the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-whitegrid')
# %matplotlib inline
# Out:
# C:\Users\pell\AppData\Local\Temp\ipykernel_26284\2205391445.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
# Read data from your prepared example .csv-file into a dataframe (define seperator)
df_crime_robbery_burglary = pd.read_csv("data/Crime/crime_robbery_burglary.csv", delimiter=';', header=None, skiprows=1, names=['INCIDENT_NUMBER', 'OFFENSE_CODE', 'OFFENSE_CODE_GROUP', 'OFFENSE_CODE_GROUP_No', 'OFFENSE_DESCRIPTION', 'DISTRICT', 'District_simple',
                                        'District_simple_No', 'REPORTING_AREA', 'OCCURRED_ON_DATE', 'Hour1', 'Start_Night', 'Start_Day', 'Night_Day', 'YEAR', 'MONTH', 'DAY_OF_WEEK', 'WE_Workday', 'WE_Workday_No', 'HOUR', 'Counts_per_hour', 'STREET', 'Lat', 'Long', 'Location'], index_col=False)

# Show the content of the dataframe:
df_crime_robbery_burglary
# Out:
#      INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP  \
# 0         I182070908           522  Residential Burglary
# 1         I182070813           522  Residential Burglary
# 2         I182070804           522  Residential Burglary
# 3         I182070706           520  Residential Burglary
# 4         I182070571           520  Residential Burglary
# ...              ...           ...                   ...
# 4746      I162087225           301               Robbery
# 4747      I162087026           301               Robbery
# 4748      I162086984           311               Robbery
# 4749      I162086982           301               Robbery
# 4750      I162086948           301               Robbery
#
#       OFFENSE_CODE_GROUP_No                OFFENSE_DESCRIPTION DISTRICT  \
# 0                         1  BURGLARY - RESIDENTIAL - NO FORCE       B2
# 1                         1  BURGLARY - RESIDENTIAL - NO FORCE       D4
# 2                         1  BURGLARY - RESIDENTIAL - NO FORCE      D14
# 3                         1     BURGLARY - RESIDENTIAL - FORCE      C11
# 4                         1     BURGLARY - RESIDENTIAL - FORCE       B2
# ...                     ...                                ...      ...
# 4746                      2                   ROBBERY - STREET       B2
# 4747                      2                   ROBBERY - STREET       A1
# 4748                      2               ROBBERY - COMMERCIAL       B3
# 4749                      2                   ROBBERY - STREET      E18
# 4750                      2                   ROBBERY - STREET       C6
#
#      District_simple  District_simple_No  REPORTING_AREA  OCCURRED_ON_DATE  \
# 0                  B                   2             911  03.09.2018 18:38
# 1                  D                   4             627  03.09.2018 03:00
# 2                  D                   4             756  03.09.2018 11:00
# 3                  C                   3             402  02.09.2018 23:33
# 4                  B                   2             317  02.09.2018 14:39
# ...              ...                 ...             ...               ...
# 4746               B                   2             909  24.10.2016 16:47
# 4747               A                   1             120  24.10.2016 03:40
# 4748               B                   2             469  23.10.2016 20:35
# 4749               E                   5             498  23.10.2016 21:18
# 4750               C                   3             214  22.10.2016 18:00
#
#       ... MONTH DAY_OF_WEEK WE_Workday WE_Workday_No  HOUR  Counts_per_hour  \
# 0     ...     9      Monday   Workdays             1    18              285
# 1     ...     9      Monday   Workdays             1     3              124
# 2     ...     9      Monday   Workdays             1    11              193
# 3     ...     9      Sunday    Weekend             2    23              231
# 4     ...     9      Sunday    Weekend             2    14              242
# ...   ...   ...         ...        ...           ...   ...              ...
# 4746  ...    10      Monday   Workdays             1    16              231
# 4747  ...    10      Monday   Workdays             1     3              124
# 4748  ...    10      Sunday    Weekend             2    20              305
# 4749  ...    10      Sunday    Weekend             2    21              303
# 4750  ...    10    Saturday    Weekend             2    18              285
#
#                STREET        Lat       Long                     Location
# 0     ANNUNCIATION RD  42.335062 -71.093168  (42.33506218, -71.09316781)
# 1     PETERBOROUGH ST  42.342802 -71.100695  (42.34280177, -71.10069510)
# 2         CHAMPNEY ST  42.352412 -71.168788  (42.35241230, -71.16878833)
# 3             BURT ST  42.284135 -71.069574  (42.28413536, -71.06957385)
# 4        HOMESTEAD ST  42.310144 -71.087592  (42.31014403, -71.08759179)
# ...               ...        ...        ...                          ...
# 4746         CABOT ST  42.333382 -71.087454  (42.33338200, -71.08745421)
# 4747      BOYLSTON ST  42.352418 -71.065255  (42.35241815, -71.06525499)
# 4748     WALK HILL ST  42.280827 -71.097547  (42.28082671, -71.09754718)
# 4749       NAVARRE ST  42.274581 -71.117665  (42.27458078, -71.11766502)
# 4750          GOLD ST  42.336295 -71.049717  (42.33629453, -71.04971704)
#
# [4751 rows x 25 columns]

# %%
df_crime_robbery_burglary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4751 entries, 0 to 4750
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   INCIDENT_NUMBER        4751 non-null   object
#  1   OFFENSE_CODE           4751 non-null   int64
#  2   OFFENSE_CODE_GROUP     4751 non-null   object
#  3   OFFENSE_CODE_GROUP_No  4751 non-null   int64
#  4   OFFENSE_DESCRIPTION    4751 non-null   object
#  5   DISTRICT               4751 non-null   object
#  6   District_simple        4751 non-null   object
#  7   District_simple_No     4751 non-null   int64
#  8   REPORTING_AREA         4751 non-null   int64
#  9   OCCURRED_ON_DATE       4751 non-null   object
#  10  Hour1                  4751 non-null   object
#  11  Start_Night            4751 non-null   object
#  12  Start_Day              4751 non-null   object
#  13  Night_Day              4751 non-null   object
#  14  YEAR                   4751 non-null   int64
#  15  MONTH                  4751 non-null   int64
#  16  DAY_OF_WEEK            4751 non-null   object
#  17  WE_Workday             4751 non-null   object
#  18  WE_Workday_No          4751 non-null   int64
#  19  HOUR                   4751 non-null   int64
#  20  Counts_per_hour        4751 non-null   int64
#  21  STREET                 4751 non-null   object
#  22  Lat                    4751 non-null   float64
#  23  Long                   4751 non-null   float64
#  24  Location               4751 non-null   object
# dtypes: float64(2), int64(9), object(14)
# memory usage: 928.1+ KB

# %% [markdown]
# #### <font color='darkblue'>__→ The master file for the offense codes__</font>

# %%
# Read data from your prepared example .csv-file into a dataframe (define seperator)
df_crime_robbery_burglary_crimecode = pd.read_csv("data/Crime/crime_robbery_burglary_crimecode.csv", delimiter=';', header=None, skiprows=1, names=[
                                                  'OFFENSE_CODE', 'OFFENSE_CODE_GROUP', 'OFFENSE_CODE_GROUP_No', 'OFFENSE_DESCRIPTION'], index_col=False)

# Show the content of the dataframe:
df_crime_robbery_burglary_crimecode
# Out:
#    OFFENSE_CODE    OFFENSE_CODE_GROUP  OFFENSE_CODE_GROUP_No  \
# 0           522  Residential Burglary                      1
# 1           520  Residential Burglary                      1
# 2           521  Residential Burglary                      1
# 3           301               Robbery                      2
# 4           361               Robbery                      2
# 5           311               Robbery                      2
# 6           381               Robbery                      2
# 7           371               Robbery                      2
# 8           351               Robbery                      2
#
#                  OFFENSE_DESCRIPTION
# 0  BURGLARY - RESIDENTIAL - NO FORCE
# 1     BURGLARY - RESIDENTIAL - FORCE
# 2   BURGLARY - RESIDENTIAL - ATTEMPT
# 3                   ROBBERY - STREET
# 4                    ROBBERY - OTHER
# 5               ROBBERY - COMMERCIAL
# 6              ROBBERY - CAR JACKING
# 7            ROBBERY - HOME INVASION
# 8                     ROBBERY - BANK

# %%
df_crime_robbery_burglary_crimecode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OFFENSE_CODE           9 non-null      int64
#  1   OFFENSE_CODE_GROUP     9 non-null      object
#  2   OFFENSE_CODE_GROUP_No  9 non-null      int64
#  3   OFFENSE_DESCRIPTION    9 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 416.0+ bytes

# %% [markdown]
# #### <font color='darkblue'>__→ Only the burglaries__</font>

# %%
# Read data from your prepared example .csv-file into a dataframe (define seperator)
df_crime_burglary = pd.read_csv("data/Crime/crime_burglary.csv", delimiter=';', header=None, skiprows=1, names=['INCIDENT_NUMBER', 'OFFENSE_CODE', 'OFFENSE_CODE_GROUP', 'OFFENSE_CODE_GROUP_No', 'OFFENSE_DESCRIPTION', 'DISTRICT', 'District_simple',
                                'District_simple_No', 'REPORTING_AREA', 'OCCURRED_ON_DATE', 'Hour1', 'Start_Night', 'Start_Day', 'Night_Day', 'YEAR', 'MONTH', 'DAY_OF_WEEK', 'WE_Workday', 'WE_Workday_No', 'HOUR', 'Counts_per_hour', 'STREET', 'Lat', 'Long', 'Location'], index_col=False)

# Show the content of the dataframe:
df_crime_burglary
# Out:
#      INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP  \
# 0         I182070908           522  Residential Burglary
# 1         I182070813           522  Residential Burglary
# 2         I182070804           522  Residential Burglary
# 3         I182070706           520  Residential Burglary
# 4         I182070571           520  Residential Burglary
# ...              ...           ...                   ...
# 2478      I162100283           522  Residential Burglary
# 2479      I162100258           521  Residential Burglary
# 2480      I162100217           521  Residential Burglary
# 2481      I162100113           520  Residential Burglary
# 2482      I162100028           520  Residential Burglary
#
#       OFFENSE_CODE_GROUP_No                OFFENSE_DESCRIPTION DISTRICT  \
# 0                         1  BURGLARY - RESIDENTIAL - NO FORCE       B2
# 1                         1  BURGLARY - RESIDENTIAL - NO FORCE       D4
# 2                         1  BURGLARY - RESIDENTIAL - NO FORCE      D14
# 3                         1     BURGLARY - RESIDENTIAL - FORCE      C11
# 4                         1     BURGLARY - RESIDENTIAL - FORCE       B2
# ...                     ...                                ...      ...
# 2478                      1  BURGLARY - RESIDENTIAL - NO FORCE       D4
# 2479                      1   BURGLARY - RESIDENTIAL - ATTEMPT      E13
# 2480                      1   BURGLARY - RESIDENTIAL - ATTEMPT       D4
# 2481                      1     BURGLARY - RESIDENTIAL - FORCE       D4
# 2482                      1     BURGLARY - RESIDENTIAL - FORCE      C11
#
#      District_simple  District_simple_No  REPORTING_AREA  OCCURRED_ON_DATE  \
# 0                  B                   2             911  03.09.2018 18:38
# 1                  D                   4             627  03.09.2018 03:00
# 2                  D                   4             756  03.09.2018 11:00
# 3                  C                   3             402  02.09.2018 23:33
# 4                  B                   2             317  02.09.2018 14:39
# ...              ...                 ...             ...               ...
# 2478               D                   4             620  08.12.2016 00:15
# 2479               E                   5             569  08.12.2016 19:51
# 2480               D                   4             152  08.12.2016 08:15
# 2481               D                   4             150  08.12.2016 12:22
# 2482               C                   3             455  07.12.2016 13:30
#
#       ... MONTH DAY_OF_WEEK WE_Workday WE_Workday_No  HOUR  Counts_per_hour  \
# 0     ...     9      Monday   Workdays             1    18              285
# 1     ...     9      Monday   Workdays             1     3              124
# 2     ...     9      Monday   Workdays             1    11              193
# 3     ...     9      Sunday    Weekend             2    23              231
# 4     ...     9      Sunday    Weekend             2    14              242
# ...   ...   ...         ...        ...           ...   ...              ...
# 2478  ...    12    Thursday   Workdays             1     0              244
# 2479  ...    12    Thursday   Workdays             1    19              274
# 2480  ...    12    Thursday   Workdays             1     8              195
# 2481  ...    12    Thursday   Workdays             1    12              258
# 2482  ...    12   Wednesday   Workdays             1    13              206
#
#                STREET        Lat       Long                     Location
# 0     ANNUNCIATION RD  42.335062 -71.093168  (42.33506218, -71.09316781)
# 1     PETERBOROUGH ST  42.342802 -71.100695  (42.34280177, -71.10069510)
# 2         CHAMPNEY ST  42.352412 -71.168788  (42.35241230, -71.16878833)
# 3             BURT ST  42.284135 -71.069574  (42.28413536, -71.06957385)
# 4        HOMESTEAD ST  42.310144 -71.087592  (42.31014403, -71.08759179)
# ...               ...        ...        ...                          ...
# 2478      HEMENWAY ST  42.346402 -71.089232  (42.34640207, -71.08923162)
# 2479    WASHINGTON ST  42.304241 -71.109672  (42.30424082, -71.10967183)
# 2480    MONTGOMERY ST  42.343746 -71.073377  (42.34374552, -71.07337676)
# 2481     DARTMOUTH ST  42.345326 -71.074974  (42.34532565, -71.07497385)
# 2482    WASHINGTON ST  42.301447 -71.076813  (42.30144714, -71.07681348)
#
# [2483 rows x 25 columns]

# %%
df_crime_burglary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2483 entries, 0 to 2482
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   INCIDENT_NUMBER        2483 non-null   object
#  1   OFFENSE_CODE           2483 non-null   int64
#  2   OFFENSE_CODE_GROUP     2483 non-null   object
#  3   OFFENSE_CODE_GROUP_No  2483 non-null   int64
#  4   OFFENSE_DESCRIPTION    2483 non-null   object
#  5   DISTRICT               2483 non-null   object
#  6   District_simple        2483 non-null   object
#  7   District_simple_No     2483 non-null   int64
#  8   REPORTING_AREA         2483 non-null   int64
#  9   OCCURRED_ON_DATE       2483 non-null   object
#  10  Hour1                  2483 non-null   object
#  11  Start_Night            2483 non-null   object
#  12  Start_Day              2483 non-null   object
#  13  Night_Day              2483 non-null   object
#  14  YEAR                   2483 non-null   int64
#  15  MONTH                  2483 non-null   int64
#  16  DAY_OF_WEEK            2483 non-null   object
#  17  WE_Workday             2483 non-null   object
#  18  WE_Workday_No          2483 non-null   int64
#  19  HOUR                   2483 non-null   int64
#  20  Counts_per_hour        2483 non-null   int64
#  21  STREET                 2483 non-null   object
#  22  Lat                    2483 non-null   float64
#  23  Long                   2483 non-null   float64
#  24  Location               2483 non-null   object
# dtypes: float64(2), int64(9), object(14)
# memory usage: 485.1+ KB

# %% [markdown]
# #### <font color='darkblue'>__→ Only the robberies__</font>

# %%
# Read data from your prepared example .csv-file into a dataframe (define seperator)
df_crime_robbery = pd.read_csv("data/Crime/crime_robbery.csv", delimiter=';', header=None, skiprows=1, names=['INCIDENT_NUMBER', 'OFFENSE_CODE', 'OFFENSE_CODE_GROUP', 'OFFENSE_CODE_GROUP_No', 'OFFENSE_DESCRIPTION', 'DISTRICT', 'District_simple',
                               'District_simple_No', 'REPORTING_AREA', 'OCCURRED_ON_DATE', 'Hour1', 'Start_Night', 'Start_Day', 'Night_Day', 'YEAR', 'MONTH', 'DAY_OF_WEEK', 'WE_Workday', 'WE_Workday_No', 'HOUR', 'Counts_per_hour', 'STREET', 'Lat', 'Long', 'Location'], index_col=False)

# Show the content of the dataframe:
df_crime_robbery
# Out:
#      INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP  OFFENSE_CODE_GROUP_No  \
# 0         I182070931           301            Robbery                      2
# 1         I182070795           301            Robbery                      2
# 2         I182070741           301            Robbery                      2
# 3         I182070621           361            Robbery                      2
# 4         I182070598           311            Robbery                      2
# ...              ...           ...                ...                    ...
# 2263      I162087225           301            Robbery                      2
# 2264      I162087026           301            Robbery                      2
# 2265      I162086984           311            Robbery                      2
# 2266      I162086982           301            Robbery                      2
# 2267      I162086948           301            Robbery                      2
#
#        OFFENSE_DESCRIPTION DISTRICT District_simple  District_simple_No  \
# 0         ROBBERY - STREET       C6               C                   3
# 1         ROBBERY - STREET      C11               C                   3
# 2         ROBBERY - STREET      D14               D                   4
# 3          ROBBERY - OTHER       A7               A                   1
# 4     ROBBERY - COMMERCIAL      A15               A                   1
# ...                    ...      ...             ...                 ...
# 2263      ROBBERY - STREET       B2               B                   2
# 2264      ROBBERY - STREET       A1               A                   1
# 2265  ROBBERY - COMMERCIAL       B3               B                   2
# 2266      ROBBERY - STREET      E18               E                   5
# 2267      ROBBERY - STREET       C6               C                   3
#
#       REPORTING_AREA  OCCURRED_ON_DATE  ... MONTH DAY_OF_WEEK WE_Workday  \
# 0                177  03.09.2018 20:48  ...     9      Monday   Workdays
# 1                362  02.09.2018 20:30  ...     9      Sunday    Weekend
# 2                805  03.09.2018 03:26  ...     9      Monday   Workdays
# 3                 23  02.09.2018 18:09  ...     9      Sunday    Weekend
# 4                 60  02.09.2018 17:15  ...     9      Sunday    Weekend
# ...              ...               ...  ...   ...         ...        ...
# 2263             909  24.10.2016 16:47  ...    10      Monday   Workdays
# 2264             120  24.10.2016 03:40  ...    10      Monday   Workdays
# 2265             469  23.10.2016 20:35  ...    10      Sunday    Weekend
# 2266             498  23.10.2016 21:18  ...    10      Sunday    Weekend
# 2267             214  22.10.2016 18:00  ...    10    Saturday    Weekend
#
#      WE_Workday_No  HOUR  Counts_per_hour             STREET        Lat  \
# 0                1    20              305  MASSACHUSETTS AVE  42.331521
# 1                2    20              305       LYNDHURST ST  42.292906
# 2                1     3              124      PORTSMOUTH ST  42.360533
# 3                2    18              285          MARION ST  42.377256
# 4                2    17              277     RUTHERFORD AVE  42.371673
# ...            ...   ...              ...                ...        ...
# 2263             1    16              231           CABOT ST  42.333382
# 2264             1     3              124        BOYLSTON ST  42.352418
# 2265             2    20              305       WALK HILL ST  42.280827
# 2266             2    21              303         NAVARRE ST  42.274581
# 2267             2    18              285            GOLD ST  42.336295
#
#            Long                     Location
# 0    -71.070853  (42.33152148, -71.07085307)
# 1    -71.069558  (42.29290563, -71.06955795)
# 2    -71.144263  (42.36053257, -71.14426332)
# 3    -71.036674  (42.37725644, -71.03667354)
# 4    -71.063264  (42.37167264, -71.06326413)
# ...         ...                          ...
# 2263 -71.087454  (42.33338200, -71.08745421)
# 2264 -71.065255  (42.35241815, -71.06525499)
# 2265 -71.097547  (42.28082671, -71.09754718)
# 2266 -71.117665  (42.27458078, -71.11766502)
# 2267 -71.049717  (42.33629453, -71.04971704)
#
# [2268 rows x 25 columns]

# %%
df_crime_robbery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2268 entries, 0 to 2267
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   INCIDENT_NUMBER        2268 non-null   object
#  1   OFFENSE_CODE           2268 non-null   int64
#  2   OFFENSE_CODE_GROUP     2268 non-null   object
#  3   OFFENSE_CODE_GROUP_No  2268 non-null   int64
#  4   OFFENSE_DESCRIPTION    2268 non-null   object
#  5   DISTRICT               2268 non-null   object
#  6   District_simple        2268 non-null   object
#  7   District_simple_No     2268 non-null   int64
#  8   REPORTING_AREA         2268 non-null   int64
#  9   OCCURRED_ON_DATE       2268 non-null   object
#  10  Hour1                  2268 non-null   object
#  11  Start_Night            2268 non-null   object
#  12  Start_Day              2268 non-null   object
#  13  Night_Day              2268 non-null   object
#  14  YEAR                   2268 non-null   int64
#  15  MONTH                  2268 non-null   int64
#  16  DAY_OF_WEEK            2268 non-null   object
#  17  WE_Workday             2268 non-null   object
#  18  WE_Workday_No          2268 non-null   int64
#  19  HOUR                   2268 non-null   int64
#  20  Counts_per_hour        2268 non-null   int64
#  21  STREET                 2268 non-null   object
#  22  Lat                    2268 non-null   float64
#  23  Long                   2268 non-null   float64
#  24  Location               2268 non-null   object
# dtypes: float64(2), int64(9), object(14)
# memory usage: 443.1+ KB

# %% [markdown]
# ## <a id='remove'></a>
# ### <font color='darkblue'>__Remove__</font>

# %%
import pandas as pd
import numpy as np

# %%
from IPython.display import Image
Image("img/pandas_logo.png", width=200)

# %% [markdown]
# ##### Source & additional information: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html

# %%
df_remove = pd.DataFrame(np.arange(12).reshape(3, 4),
                         columns=['A', 'B', 'C', 'D'])
df_remove
# Out:
#    A  B   C   D
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
df_remove.drop(['B', 'C'], axis=1)
# Out:
#    A   D
# 0  0   3
# 1  4   7
# 2  8  11

# %%
df_remove.drop(columns=['B', 'C'])
# Out:
#    A   D
# 0  0   3
# 1  4   7
# 2  8  11

# %%
df_remove.drop([0, 1])
# Out:
#    A  B   C   D
# 2  8  9  10  11

# %%
midx = pd.MultiIndex(levels=[['lama', 'cow', 'falcon'],
                             ['speed', 'weight', 'length']],
                     codes=[[0, 0, 0, 1, 1, 1, 2, 2, 2],
                            [0, 1, 2, 0, 1, 2, 0, 1, 2]])

df_remove = pd.DataFrame(index=midx, columns=['big', 'small'],
                         data=[[45, 30], [200, 100], [1.5, 1], [30, 20],
                               [250, 150], [1.5, 0.8], [320, 250],
                               [1, 0.8], [0.3, 0.2]])
df_remove
# Out:
#                  big  small
# lama   speed    45.0   30.0
#        weight  200.0  100.0
#        length    1.5    1.0
# cow    speed    30.0   20.0
#        weight  250.0  150.0
#        length    1.5    0.8
# falcon speed   320.0  250.0
#        weight    1.0    0.8
#        length    0.3    0.2

# %%
df_remove.drop(index='cow', columns='small')
# Out:
#                  big
# lama   speed    45.0
#        weight  200.0
#        length    1.5
# falcon speed   320.0
#        weight    1.0
#        length    0.3

# %%
df_remove.drop(index='length', level=1)
# Out:
#                  big  small
# lama   speed    45.0   30.0
#        weight  200.0  100.0
# cow    speed    30.0   20.0
#        weight  250.0  150.0
# falcon speed   320.0  250.0
#        weight    1.0    0.8

# %% [markdown]
# ###
# ### <font color='darkblue'>__Applying Remove on Crime Data__</font>

# %%
df_remove_crime = df
df_remove_crime.drop(columns=['OFFENSE_CODE_GROUP', 'OFFENSE_DESCRIPTION',
                     'DISTRICT', 'District_simple', 'DAY_OF_WEEK', 'WE_Workday', 'STREET'])
# Out:
#      INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP_No  District_simple_No  \
# 0         I182070908           522                      1                   2
# 1         I182070813           522                      1                   4
# 2         I182070804           522                      1                   4
# 3         I182070706           520                      1                   3
# 4         I182070571           520                      1                   2
# ...              ...           ...                    ...                 ...
# 4746      I162087225           301                      2                   2
# 4747      I162087026           301                      2                   1
# 4748      I162086984           311                      2                   2
# 4749      I162086982           301                      2                   5
# 4750      I162086948           301                      2                   3
#
#       REPORTING_AREA  OCCURRED_ON_DATE     Hour1 Start_Night Start_Day  \
# 0                911  03.09.2018 18:38  18:38:00    17:00:00  08:00:00
# 1                627  03.09.2018 03:00  03:00:00    17:00:00  08:00:00
# 2                756  03.09.2018 11:00  11:00:00    17:00:00  08:00:00
# 3                402  02.09.2018 23:33  23:33:00    17:00:00  08:00:00
# 4                317  02.09.2018 14:39  14:39:00    17:00:00  08:00:00
# ...              ...               ...       ...         ...       ...
# 4746             909  24.10.2016 16:47  16:47:00    17:00:00  08:00:00
# 4747             120  24.10.2016 03:40  03:40:00    17:00:00  08:00:00
# 4748             469  23.10.2016 20:35  20:35:00    17:00:00  08:00:00
# 4749             498  23.10.2016 21:18  21:18:00    17:00:00  08:00:00
# 4750             214  22.10.2016 18:00  18:00:00    17:00:00  08:00:00
#
#      Night_Day  YEAR  MONTH  WE_Workday_No  HOUR  Counts_per_hour        Lat  \
# 0        Night  2018      9              1    18              285  42.335062
# 1        Night  2018      9              1     3              124  42.342802
# 2          Day  2018      9              1    11              193  42.352412
# 3        Night  2018      9              2    23              231  42.284135
# 4          Day  2018      9              2    14              242  42.310144
# ...        ...   ...    ...            ...   ...              ...        ...
# 4746       Day  2016     10              1    16              231  42.333382
# 4747     Night  2016     10              1     3              124  42.352418
# 4748     Night  2016     10              2    20              305  42.280827
# 4749     Night  2016     10              2    21              303  42.274581
# 4750     Night  2016     10              2    18              285  42.336295
#
#            Long                     Location
# 0    -71.093168  (42.33506218, -71.09316781)
# 1    -71.100695  (42.34280177, -71.10069510)
# 2    -71.168788  (42.35241230, -71.16878833)
# 3    -71.069574  (42.28413536, -71.06957385)
# 4    -71.087592  (42.31014403, -71.08759179)
# ...         ...                          ...
# 4746 -71.087454  (42.33338200, -71.08745421)
# 4747 -71.065255  (42.35241815, -71.06525499)
# 4748 -71.097547  (42.28082671, -71.09754718)
# 4749 -71.117665  (42.27458078, -71.11766502)
# 4750 -71.049717  (42.33629453, -71.04971704)
#
# [4751 rows x 18 columns]

# %% [markdown]
# ## <a id='concatenate'></a>
# ### <font color='darkblue'>__Concatenate__</font>

# %%
from IPython.display import Image
Image("img/pandas_logo.png", width=200)

# %%
from IPython.display import Image
Image("img/concat.png", width=350)

# %% [markdown]
# ##### Source & additional information: https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %%
df_concat1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                           'B': ['B0', 'B1', 'B2', 'B3'],
                           'C': ['C0', 'C1', 'C2', 'C3'],
                           'D': ['D0', 'D1', 'D2', 'D3']},
                          index=[0, 1, 2, 3])

df_concat2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                           'B': ['B4', 'B5', 'B6', 'B7'],
                           'C': ['C4', 'C5', 'C6', 'C7'],
                           'D': ['D4', 'D5', 'D6', 'D7']},
                          index=[4, 5, 6, 7])

df_concat3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                           'B': ['B8', 'B9', 'B10', 'B11'],
                           'C': ['C8', 'C9', 'C10', 'C11'],
                           'D': ['D8', 'D9', 'D10', 'D11']},
                          index=[8, 9, 10, 11])

frames = [df_concat1, df_concat2, df_concat3]

result = pd.concat(frames)

result
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
result = pd.concat(frames, keys=['x', 'y', 'z'])

# %%
result.loc['y']
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df_concat4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                           'D': ['D2', 'D3', 'D6', 'D7'],
                           'F': ['F2', 'F3', 'F6', 'F7']},
                          index=[2, 3, 6, 7])

result = pd.concat([df_concat1, df_concat4], axis=1, sort=False)

# %%
result = pd.concat([df_concat1, df_concat4], axis=1, join='inner')

# %%
result = pd.concat([df_concat1, df_concat4], axis=1).reindex(df_concat1.index)

# %%
pd.concat([df_concat1, df_concat4.reindex(df_concat1.index)], axis=1)
# Out:
#     A   B   C   D    B    D    F
# 0  A0  B0  C0  D0  NaN  NaN  NaN
# 1  A1  B1  C1  D1  NaN  NaN  NaN
# 2  A2  B2  C2  D2   B2   D2   F2
# 3  A3  B3  C3  D3   B3   D3   F3

# %% [markdown]
# ###
# ### <font color='darkblue'>__Applying Concatenate on Crime Data__</font>

# %%
frames = [df_crime_burglary, df_crime_robbery]

result = pd.concat(frames)

result
# Out:
#      INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP  \
# 0         I182070908           522  Residential Burglary
# 1         I182070813           522  Residential Burglary
# 2         I182070804           522  Residential Burglary
# 3         I182070706           520  Residential Burglary
# 4         I182070571           520  Residential Burglary
# ...              ...           ...                   ...
# 2263      I162087225           301               Robbery
# 2264      I162087026           301               Robbery
# 2265      I162086984           311               Robbery
# 2266      I162086982           301               Robbery
# 2267      I162086948           301               Robbery
#
#       OFFENSE_CODE_GROUP_No                OFFENSE_DESCRIPTION DISTRICT  \
# 0                         1  BURGLARY - RESIDENTIAL - NO FORCE       B2
# 1                         1  BURGLARY - RESIDENTIAL - NO FORCE       D4
# 2                         1  BURGLARY - RESIDENTIAL - NO FORCE      D14
# 3                         1     BURGLARY - RESIDENTIAL - FORCE      C11
# 4                         1     BURGLARY - RESIDENTIAL - FORCE       B2
# ...                     ...                                ...      ...
# 2263                      2                   ROBBERY - STREET       B2
# 2264                      2                   ROBBERY - STREET       A1
# 2265                      2               ROBBERY - COMMERCIAL       B3
# 2266                      2                   ROBBERY - STREET      E18
# 2267                      2                   ROBBERY - STREET       C6
#
#      District_simple  District_simple_No  REPORTING_AREA  OCCURRED_ON_DATE  \
# 0                  B                   2             911  03.09.2018 18:38
# 1                  D                   4             627  03.09.2018 03:00
# 2                  D                   4             756  03.09.2018 11:00
# 3                  C                   3             402  02.09.2018 23:33
# 4                  B                   2             317  02.09.2018 14:39
# ...              ...                 ...             ...               ...
# 2263               B                   2             909  24.10.2016 16:47
# 2264               A                   1             120  24.10.2016 03:40
# 2265               B                   2             469  23.10.2016 20:35
# 2266               E                   5             498  23.10.2016 21:18
# 2267               C                   3             214  22.10.2016 18:00
#
#       ... MONTH DAY_OF_WEEK WE_Workday WE_Workday_No  HOUR  Counts_per_hour  \
# 0     ...     9      Monday   Workdays             1    18              285
# 1     ...     9      Monday   Workdays             1     3              124
# 2     ...     9      Monday   Workdays             1    11              193
# 3     ...     9      Sunday    Weekend             2    23              231
# 4     ...     9      Sunday    Weekend             2    14              242
# ...   ...   ...         ...        ...           ...   ...              ...
# 2263  ...    10      Monday   Workdays             1    16              231
# 2264  ...    10      Monday   Workdays             1     3              124
# 2265  ...    10      Sunday    Weekend             2    20              305
# 2266  ...    10      Sunday    Weekend             2    21              303
# 2267  ...    10    Saturday    Weekend             2    18              285
#
#                STREET        Lat       Long                     Location
# 0     ANNUNCIATION RD  42.335062 -71.093168  (42.33506218, -71.09316781)
# 1     PETERBOROUGH ST  42.342802 -71.100695  (42.34280177, -71.10069510)
# 2         CHAMPNEY ST  42.352412 -71.168788  (42.35241230, -71.16878833)
# 3             BURT ST  42.284135 -71.069574  (42.28413536, -71.06957385)
# 4        HOMESTEAD ST  42.310144 -71.087592  (42.31014403, -71.08759179)
# ...               ...        ...        ...                          ...
# 2263         CABOT ST  42.333382 -71.087454  (42.33338200, -71.08745421)
# 2264      BOYLSTON ST  42.352418 -71.065255  (42.35241815, -71.06525499)
# 2265     WALK HILL ST  42.280827 -71.097547  (42.28082671, -71.09754718)
# 2266       NAVARRE ST  42.274581 -71.117665  (42.27458078, -71.11766502)
# 2267          GOLD ST  42.336295 -71.049717  (42.33629453, -71.04971704)
#
# [4751 rows x 25 columns]

# %% [markdown]
# ## <a id='join'></a>
# ### <font color='darkblue'>__Join__</font>

# %%
from IPython.display import Image
Image("img/pandas_logo.png", width=200)

# %% [markdown]
# ##### Source & additional information: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.join.html

# %%
df_join = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3', 'K4', 'K5'],
                        'A': ['A0', 'A1', 'A2', 'A3', 'A4', 'A5']})
df_join
# Out:
#   key   A
# 0  K0  A0
# 1  K1  A1
# 2  K2  A2
# 3  K3  A3
# 4  K4  A4
# 5  K5  A5

# %%
other = pd.DataFrame({'key': ['K0', 'K1', 'K2'],
                      'B': ['B0', 'B1', 'B2']})
other
# Out:
#   key   B
# 0  K0  B0
# 1  K1  B1
# 2  K2  B2

# %%
df_join.join(other, lsuffix='_caller', rsuffix='_other')
# Out:
#   key_caller   A key_other    B
# 0         K0  A0        K0   B0
# 1         K1  A1        K1   B1
# 2         K2  A2        K2   B2
# 3         K3  A3       NaN  NaN
# 4         K4  A4       NaN  NaN
# 5         K5  A5       NaN  NaN

# %%
df_join.set_index('key').join(other.set_index('key'))
# Out:
#       A    B
# key
# K0   A0   B0
# K1   A1   B1
# K2   A2   B2
# K3   A3  NaN
# K4   A4  NaN
# K5   A5  NaN

# %%
df_join.join(other.set_index('key'), on='key')
# Out:
#   key   A    B
# 0  K0  A0   B0
# 1  K1  A1   B1
# 2  K2  A2   B2
# 3  K3  A3  NaN
# 4  K4  A4  NaN
# 5  K5  A5  NaN

# %% [markdown]
# ###
# ### <font color='darkblue'>__Applying Join on Crime Data__</font>

# %%
df.join(df_crime_robbery_burglary_crimecode,
        lsuffix='_caller', rsuffix='_other')
# Out:
#      INCIDENT_NUMBER  OFFENSE_CODE_caller OFFENSE_CODE_GROUP_caller  \
# 0         I182070908                  522      Residential Burglary
# 1         I182070813                  522      Residential Burglary
# 2         I182070804                  522      Residential Burglary
# 3         I182070706                  520      Residential Burglary
# 4         I182070571                  520      Residential Burglary
# ...              ...                  ...                       ...
# 4746      I162087225                  301                   Robbery
# 4747      I162087026                  301                   Robbery
# 4748      I162086984                  311                   Robbery
# 4749      I162086982                  301                   Robbery
# 4750      I162086948                  301                   Robbery
#
#       OFFENSE_CODE_GROUP_No_caller         OFFENSE_DESCRIPTION_caller  \
# 0                                1  BURGLARY - RESIDENTIAL - NO FORCE
# 1                                1  BURGLARY - RESIDENTIAL - NO FORCE
# 2                                1  BURGLARY - RESIDENTIAL - NO FORCE
# 3                                1     BURGLARY - RESIDENTIAL - FORCE
# 4                                1     BURGLARY - RESIDENTIAL - FORCE
# ...                            ...                                ...
# 4746                             2                   ROBBERY - STREET
# 4747                             2                   ROBBERY - STREET
# 4748                             2               ROBBERY - COMMERCIAL
# 4749                             2                   ROBBERY - STREET
# 4750                             2                   ROBBERY - STREET
#
#      DISTRICT District_simple  District_simple_No  REPORTING_AREA  \
# 0          B2               B                   2             911
# 1          D4               D                   4             627
# 2         D14               D                   4             756
# 3         C11               C                   3             402
# 4          B2               B                   2             317
# ...       ...             ...                 ...             ...
# 4746       B2               B                   2             909
# 4747       A1               A                   1             120
# 4748       B3               B                   2             469
# 4749      E18               E                   5             498
# 4750       C6               C                   3             214
#
#       OCCURRED_ON_DATE  ... HOUR Counts_per_hour           STREET        Lat  \
# 0     03.09.2018 18:38  ...   18             285  ANNUNCIATION RD  42.335062
# 1     03.09.2018 03:00  ...    3             124  PETERBOROUGH ST  42.342802
# 2     03.09.2018 11:00  ...   11             193      CHAMPNEY ST  42.352412
# 3     02.09.2018 23:33  ...   23             231          BURT ST  42.284135
# 4     02.09.2018 14:39  ...   14             242     HOMESTEAD ST  42.310144
# ...                ...  ...  ...             ...              ...        ...
# 4746  24.10.2016 16:47  ...   16             231         CABOT ST  42.333382
# 4747  24.10.2016 03:40  ...    3             124      BOYLSTON ST  42.352418
# 4748  23.10.2016 20:35  ...   20             305     WALK HILL ST  42.280827
# 4749  23.10.2016 21:18  ...   21             303       NAVARRE ST  42.274581
# 4750  22.10.2016 18:00  ...   18             285          GOLD ST  42.336295
#
#            Long                     Location OFFENSE_CODE_other  \
# 0    -71.093168  (42.33506218, -71.09316781)              522.0
# 1    -71.100695  (42.34280177, -71.10069510)              520.0
# 2    -71.168788  (42.35241230, -71.16878833)              521.0
# 3    -71.069574  (42.28413536, -71.06957385)              301.0
# 4    -71.087592  (42.31014403, -71.08759179)              361.0
# ...         ...                          ...                ...
# 4746 -71.087454  (42.33338200, -71.08745421)                NaN
# 4747 -71.065255  (42.35241815, -71.06525499)                NaN
# 4748 -71.097547  (42.28082671, -71.09754718)                NaN
# 4749 -71.117665  (42.27458078, -71.11766502)                NaN
# 4750 -71.049717  (42.33629453, -71.04971704)                NaN
#
#      OFFENSE_CODE_GROUP_other  OFFENSE_CODE_GROUP_No_other  \
# 0        Residential Burglary                          1.0
# 1        Residential Burglary                          1.0
# 2        Residential Burglary                          1.0
# 3                     Robbery                          2.0
# 4                     Robbery                          2.0
# ...                       ...                          ...
# 4746                      NaN                          NaN
# 4747                      NaN                          NaN
# 4748                      NaN                          NaN
# 4749                      NaN                          NaN
# 4750                      NaN                          NaN
#
#               OFFENSE_DESCRIPTION_other
# 0     BURGLARY - RESIDENTIAL - NO FORCE
# 1        BURGLARY - RESIDENTIAL - FORCE
# 2      BURGLARY - RESIDENTIAL - ATTEMPT
# 3                      ROBBERY - STREET
# 4                       ROBBERY - OTHER
# ...                                 ...
# 4746                                NaN
# 4747                                NaN
# 4748                                NaN
# 4749                                NaN
# 4750                                NaN
#
# [4751 rows x 29 columns]

# %% [markdown]
# ## <a id='merge'></a>
# ### <font color='darkblue'>__Merge__</font>

# %%
from IPython.display import Image
Image("img/pandas_logo.png", width=200)

# %% [markdown]
# ##### Source & additional information: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html

# %%
df_merge1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                          'B': ['B0', 'B1', 'B2', 'B3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']},
                         index=[0, 1, 2, 3])

df_merge2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                          'B': ['B4', 'B5', 'B6', 'B7'],
                          'C': ['C4', 'C5', 'C6', 'C7'],
                          'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])

df_merge3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                          'B': ['B8', 'B9', 'B10', 'B11'],
                          'C': ['C8', 'C9', 'C10', 'C11'],
                          'D': ['D8', 'D9', 'D10', 'D11']},
                         index=[8, 9, 10, 11])

df_merge4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                          'D': ['D2', 'D3', 'D6', 'D7'],
                          'F': ['F2', 'F3', 'F6', 'F7']},
                         index=[2, 3, 6, 7])

frames = [df_merge1, df_merge2, df_merge3]

# %%
df_merge1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
                          'value': [1, 2, 3, 5]})
df_merge1
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5

# %%
df_merge2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
                          'value': [5, 6, 7, 8]})
df_merge2
# Out:
#   rkey  value
# 0  foo      5
# 1  bar      6
# 2  baz      7
# 3  foo      8

# %%
df_merge1.merge(df_merge2, left_on='lkey', right_on='rkey')
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  foo        5  foo        5
# 3  foo        5  foo        8
# 4  bar        2  bar        6
# 5  baz        3  baz        7

# %%
df_merge1.merge(df_merge2, left_on='lkey', right_on='rkey',
                suffixes=('_left', '_right'))
# Out:
#   lkey  value_left rkey  value_right
# 0  foo           1  foo            5
# 1  foo           1  foo            8
# 2  foo           5  foo            5
# 3  foo           5  foo            8
# 4  bar           2  bar            6
# 5  baz           3  baz            7

# %% [markdown]
# ###
# ### <font color='darkblue'>__Applying Merge on Crime Data__</font>

# %%
df_crime_burglary.merge(
    df_crime_robbery, left_on='OFFENSE_CODE_GROUP_No', right_on='OFFENSE_CODE_GROUP_No')
# Out:
# Empty DataFrame
# Columns: [INCIDENT_NUMBER_x, OFFENSE_CODE_x, OFFENSE_CODE_GROUP_x, OFFENSE_CODE_GROUP_No, OFFENSE_DESCRIPTION_x, DISTRICT_x, District_simple_x, District_simple_No_x, REPORTING_AREA_x, OCCURRED_ON_DATE_x, Hour1_x, Start_Night_x, Start_Day_x, Night_Day_x, YEAR_x, MONTH_x, DAY_OF_WEEK_x, WE_Workday_x, WE_Workday_No_x, HOUR_x, Counts_per_hour_x, STREET_x, Lat_x, Long_x, Location_x, INCIDENT_NUMBER_y, OFFENSE_CODE_y, OFFENSE_CODE_GROUP_y, OFFENSE_DESCRIPTION_y, DISTRICT_y, District_simple_y, District_simple_No_y, REPORTING_AREA_y, OCCURRED_ON_DATE_y, Hour1_y, Start_Night_y, Start_Day_y, Night_Day_y, YEAR_y, MONTH_y, DAY_OF_WEEK_y, WE_Workday_y, WE_Workday_No_y, HOUR_y, Counts_per_hour_y, STREET_y, Lat_y, Long_y, Location_y]
# Index: []
#
# [0 rows x 49 columns]

# %% [markdown]
# ## <a id='aggregate'></a>
# ### <font color='darkblue'>__Aggregate__</font>

# %%
from IPython.display import Image
Image("img/pandas_logo.png", width=200)

# %% [markdown]
# ##### Source & additional information: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.aggregate.html

# %%
df_aggr = pd.DataFrame([[1, 2, 3],
                        [4, 5, 6],
                        [7, 8, 9],
                        [np.nan, np.nan, np.nan]],
                       columns=['A', 'B', 'C'])

# %%
df_aggr.agg(['sum', 'min'])
# Out:
#         A     B     C
# sum  12.0  15.0  18.0
# min   1.0   2.0   3.0

# %%
df_aggr.agg({'A': ['sum', 'min'], 'B': ['min', 'max']})
# Out:
#         A    B
# sum  12.0  NaN
# min   1.0  2.0
# max   NaN  8.0

# %%
df_aggr.agg("mean", axis="columns")
# Out:
# 0    2.0
# 1    5.0
# 2    8.0
# 3    NaN
# dtype: float64

# %% [markdown]
# ###
# ### <font color='darkblue'>__Applying Aggregate on Crime Data__</font>

# %%
df.agg(['sum', 'min'])
# Out:
#                                        INCIDENT_NUMBER  OFFENSE_CODE  \
# sum  I182070908I182070813I182070804I182070706I18207...       2010476
# min                                         I162086948           301
#
#                                     OFFENSE_CODE_GROUP  OFFENSE_CODE_GROUP_No  \
# sum  Residential BurglaryResidential BurglaryReside...                   7019
# min                               Residential Burglary                      1
#
#                                    OFFENSE_DESCRIPTION  \
# sum  BURGLARY - RESIDENTIAL - NO FORCEBURGLARY - RE...
# min                   BURGLARY - RESIDENTIAL - ATTEMPT
#
#                                               DISTRICT  \
# sum  B2D4D14C11B2B2C11D4C11D4D14C11A1B3B3A1C11E18D1...
# min                                                 A1
#
#                                        District_simple  District_simple_No  \
# sum  BDDCBBCDCDDCABBACEDEEDBDDCBBADEDBCCEDDDABDCEAB...               13738
# min                                                  A                   1
#
#      REPORTING_AREA                                   OCCURRED_ON_DATE  ...  \
# sum         1883859  03.09.2018 18:3803.09.2018 03:0003.09.2018 11:...  ...
# min               2                                   01.01.2017 03:00  ...
#
#      MONTH                                        DAY_OF_WEEK  \
# sum  29881  MondayMondayMondaySundaySundayFridaySaturdayFr...
# min      1                                             Friday
#
#                                             WE_Workday WE_Workday_No   HOUR  \
# sum  WorkdaysWorkdaysWorkdaysWeekendWeekendWorkdays...          5997  62531
# min                                            Weekend             1      0
#
#      Counts_per_hour                                             STREET  \
# sum          1087962  ANNUNCIATION RDPETERBOROUGH STCHAMPNEY STBURT ...
# min               77                                               A ST
#
#                Lat           Long  \
# sum  201076.103008 -337715.579321
# min      42.232870     -71.172440
#
#                                               Location
# sum  (42.33506218, -71.09316781)(42.34280177, -71.1...
# min                        (42.23287025, -71.13004959)
#
# [2 rows x 25 columns]

# %%
# Select only certain columns of your dataframe (if needed)
df_aggr_crime = df[["OFFENSE_CODE_GROUP_No", "Counts_per_hour"]]
df_aggr_crime
# Out:
#       OFFENSE_CODE_GROUP_No  Counts_per_hour
# 0                         1              285
# 1                         1              124
# 2                         1              193
# 3                         1              231
# 4                         1              242
# ...                     ...              ...
# 4746                      2              231
# 4747                      2              124
# 4748                      2              305
# 4749                      2              303
# 4750                      2              285
#
# [4751 rows x 2 columns]

# %%
df_aggr_crime.agg(['sum', 'min', 'max'])
# Out:
#      OFFENSE_CODE_GROUP_No  Counts_per_hour
# sum                   7019          1087962
# min                      1               77
# max                      2              305

# %% [markdown]
# ## <a id='groupby'></a>
# ### <font color='darkblue'>__Group by__</font>

# %%
from IPython.display import Image
Image("img/pandas_logo.png", width=200)

# %% [markdown]
# ##### Source & additional information: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html

# %%
df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
                              'Parrot', 'Parrot'],
                   'Max Speed': [380., 370., 24., 26.]})
df
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0

# %%
df.groupby(['Animal']).mean()
# Out:
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0

# %%
arrays = [['Falcon', 'Falcon', 'Parrot', 'Parrot'],
          ['Captive', 'Wild', 'Captive', 'Wild']]
index = pd.MultiIndex.from_arrays(arrays, names=('Animal', 'Type'))
df = pd.DataFrame({'Max Speed': [390., 350., 30., 20.]},
                  index=index)
df
# Out:
#                 Max Speed
# Animal Type
# Falcon Captive      390.0
#        Wild         350.0
# Parrot Captive       30.0
#        Wild          20.0

# %%
df.groupby(level=0).mean()
# Out:
#         Max Speed
# Animal
# Falcon      370.0
# Parrot       25.0

# %%
df.groupby(level="Type").mean()
# Out:
#          Max Speed
# Type
# Captive      210.0
# Wild         185.0

# %% [markdown]
# ###
# ### <font color='darkblue'>__Applying Group by on Crime Data__</font>

# %%
df_aggr_crime.groupby('OFFENSE_CODE_GROUP_No').agg(['sum', 'min', 'max'])
# Out:
#                       Counts_per_hour
#                                   sum min  max
# OFFENSE_CODE_GROUP_No
# 1                              555720  77  305
# 2                              532242  77  305
